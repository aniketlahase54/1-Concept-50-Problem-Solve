# %%
# Create a variable name and store your name.
name = "aniket"

# %%
# Create a variable age and store your age.
age = 23

# %%
# Create variables for name, age, and city and print them.
name = "Aniket"
age = 23
city = "Muktainagar"
print(name)
print(age)
print(city)
# Out:
# Aniket
# 23
# Muktainagar

# %%
# Store your college name in a variable and print it.
college_name = "SSBT COET JALGAON"
print(college_name)
# Out:
# SSBT COET JALGAON

# %%
# Create a variable country and assign "India".
country = "India"

# %%
# Store your favorite programming language in a variable.
lan = "python"

# %%
# Create three variables a, b, and c and assign numbers to them.
a = 23
b = 34
c = 45

# %%
# Store your birth year in a variable and print it.
DOB = 20-09-2004

# %%
# Create a variable is_student and assign True.
is_student = True

# %%
# Create a variable salary and assign a value.
salary = 50000

# %%
# Store two numbers in variables and print their sum.
a = 5
b = 3
print(a + b)
# Out:
# 8

# %%
# Store two numbers and calculate their difference.
a = 5
b = 3
print(a - b)
# Out:
# 2

# %%
# Store two numbers and calculate their product.
a = 5
b = 3
print(a * b)
# Out:
# 15

# %%
# Store two numbers and calculate their division.
a = 5
b = 3
print(a / b)
# Out:
# 1.6666666666666667

# %%
# Store length and width in variables and calculate the area of a rectangle.
length = 15
width  = 10
area = length*width
print(area)
# Out:
# 150

# %%
# Store side length in a variable and calculate the area of a square.
side = 5
area = side * side
print(area)
# Out:
# 25

# %%
# Store radius in a variable and calculate the area of a circle.
radius = 5
area = 3.14*radius*radius
print(area)
# Out:
# 78.5

# %%
# Store principal, rate, and time and calculate simple interest.
principal = 45000
rate = 9.5
time = 6
SI = (principal) * (rate) * ( time) / 100
print(SI)
# Out:
# 25650.0

# %%
# Store marks of 5 subjects and calculate total marks.
math = 76
eng = 65
bio = 78
phy = 54
che = 65
total = math + eng + bio + phy + che
print(total)
# Out:
# 338

# %%
# Store marks of 5 subjects and calculate percentage.
math = 34
eng = 62
bio = 74
phy = 54
che = 43
percentage = (math + eng + bio + phy + che) / 500 * 100
print(percentage)
# Out:
# 53.400000000000006

# %%
# Create variables for student name, age, course, and college and print all details.
name = "Aniket"
age = 23
course = "computer"
clg = "SSBT"

print(name)
print(age)
print(course)
print(clg)
# Out:
# Aniket
# 23
# computer
# SSBT

# %%
# Store employee name, employee ID, department, and salary in variables.
emp_name = "aniket"
emp_id = 1
dept = "computer"
salary = 50000

# %%
# Store product name, price, and quantity. Calculate total price.
name = "chips"
price = 5
quantity = 3
total_price = price * quantity
print(total_price)
# Out:
# 15

# %%
# Store first_name and last_name and create a full name.
first_name = "aniket"
last_name = "lahase"
full_name = first_name +" "+ last_name
print(full_name)
# Out:
# aniket lahase

# %%
# Store first_name, middle_name, and last_name and print the complete name.
first_name = "aniket"
middle_name = "bhagwat"
last_name = "lahase"
full_name = first_name +" "+ middle_name +" "+ last_name
print(full_name)
# Out:
# aniket bhagwat lahase

# %%
# Store a person's age and calculate their age after 10 years.
person_age = 15
age_after = 10 + person_age
print(age_after)
# Out:
# 25

# %%
# Store current year and birth year and calculate age.
CY = 2026
DOB = 2004
age = CY - DOB
print(age)
# Out:
# 22

# %%
# Store distance and time and calculate speed.
distance =  60
time = 30
speed = distance / time
print(speed)
# Out:
# 2.0

# %%
# Store total seconds and convert them into hours, minutes and seconds.
seconds = 12059

hours = seconds // 3600
remaining_seconds = seconds % 3600

minute = remaining_seconds // 60
second = remaining_seconds % 60


print(hours)
print(minute)
print(second)
# Out:
# 3
# 20
# 59

# %%
# Store temperature in Celsius and convert it to Fahrenheit.
temperature = 40

fah = (temperature * 9/5) + 32

print(fah)
# Out:
# 104.0

# %%
# Swap two variables without using a third variable.
a = 20 
b = 54
a,b =b,a
print(a,b)
# Out:
# 54 20

# %%
# Create three variables a, b, c and rotate their values.
a = 5
b = 7
c = 9
a,b,c = b,c,a
print(a,b,c)
# Out:
# 7 9 5

# %%
# Store a number and increase its value by 10.
num = 45
increase10 = num + 10
print(increase10)
# Out:
# 55

# %%
# Store a number and decrease its value by 5.
num = 34
decrease5 = num - 5
print(decrease5)
# Out:
# 29

# %%
# Store a price and apply a 10% discount.
price = 1000
discount = price *(10/100)
total = price - discount
print(total)
# Out:
# 900.0

# %%
# Store salary and calculate salary after a 15% increment.
salary = 56000
increment = salary *(15/100)
afterincrement = salary + increment
print(afterincrement)
# Out:
# 64400.0

# %%
# Store total bill and number of people and calculate each person's share.
total_bill = 1500
people = 5
each_person = total_bill / people
print(each_person)
# Out:
# 300.0

# %%
# Store distance in kilometers and convert it to meters.
distance = 2
meter = distance * 1000
print(meter)
# Out:
# 2000

# %%
# Store weight in kilograms and convert it to grams.
weight = 75
gram = weight * 1000
print(gram)
# Out:
# 75000

# %%
# Create variables for an employee's basic salary, HRA, and DA and calculate gross salary.
basic_salary = 20000
HRA = basic_salary *(50/100)
DA = basic_salary *(40/100)

gross_salary = basic_salary + HRA + DA
print(gross_salary)
# Out:
# 38000.0

# %%
# Store product price and GST percentage and calculate final price.
product_price = 560
GST = product_price *(18/100)
final_price = product_price + GST
print(final_price)
# Out:
# 660.8

# %%
# Store shopping cart item price and quantity and calculate the total bill.
price = 576
quantity = 4
total_bill = price * quantity
print(total_bill)
# Out:
# 2304

# %%
# Store monthly salary and calculate annual salary.
monthly_salary = 56000
annual_salary = monthly_salary * 12
print(annual_salary)
# Out:
# 672000

# %%
# Store monthly expenses for rent, food, travel, and entertainment and calculate total expenses.
rent = 5500
food = 4500
travel = 1000
entertainment = 2500

total_expenses = rent + food + travel + entertainment

print(total_expenses)
# Out:
# 13500

# %%
# Store monthly income and expenses and calculate monthly savings.
monthly_salary = 56000
total_expenses = 13500

monthly_saving = monthly_salary - total_expenses
print(monthly_saving)
# Out:
# 42500

# %%
# Store car price, down payment, and loan amount and calculate the remaining amount.
price = 1650000
DP = 450000
RA = price - DP
print(RA)
# Out:
# 1200000

# %%
# Store total_distance and fuel_consumed and calculate car mileage.
total_distance = 150
fuel_consumed = 3.5

mileage = total_distance / fuel_consumed
print(mileage)
# Out:
# 42.857142857142854
