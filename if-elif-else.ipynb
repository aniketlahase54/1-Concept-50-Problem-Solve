# %%
# Basic if — 1–10
# Given age = 20, print "Eligible" if age is 18 or above.
age = 20

if age >=18:
    print("Eligible")
# Out:
# Eligible

# %%
# Given number = 10, print "Positive" if the number is greater than 0.
number = 10
if number > 0:
    print("Positive")
# Out:
# Positive

# %%
# Given marks = 75, print "Passed" if marks are 40 or above.
marks = 75

if marks >=40:
    print("passed")
# Out:
# passed

# %%
# Given temperature = 35, print "Hot" if temperature is above 30.
temperature = 35

if temperature > 30:
    print("Hot")
# Out:
# Hot

# %%
# Given salary = 50000, print "High Salary" if salary is above 40000.
salary = 50000
if salary > 40000:
    print("High salary")
# Out:
# High salary

# %%
# Given number = 8, print "Even" if the number is divisible by 2.
number = 8
if number % 2==0:
    print("Even")
# Out:
# Even

# %%
# Given password = "Python123", print "Valid" if the password is not empty.
password = "Python123"

if password != "":
    print("Valid")
# Out:
# Valid

# %%
# Given name = "Aniket", print "Welcome" if the name is "Aniket".
name = "Aniket"

if name == "Aniket":
    print("Welcome")
# Out:
# Welcome

# %%
# Given age = 25, print "Adult" if age is 18 or above.
age = 25

if age >=18:
    print("Adult")
# Out:
# Adult

# %%
# Given balance = 5000, print "Sufficient Balance" if balance is above 1000.
balance = 5000

if balance > 1000:
    print("Sufficient Balance")
# Out:
# Sufficient Balance

# %%
# 🟡 if-else — 11–25
# Check whether a number is positive or negative.
num = 87

if num > 0 :
    print("positive")

else:
    print("Negative")
# Out:
# positive

# %%
# Check whether a number is even or odd.
num = 43

if num%2==0:
    print("Even Number")

else:  
    print("Odd Number")
# Out:
# Odd Number

# %%
# Check whether a student has passed or failed.
marks = 67

if marks > 35 :
    print("passed")

else:
    print("failed")
# Out:
# passed

# %%
# Check whether a person is eligible to vote.
age  = 15

if age > 18:
    print("eligible for vote")

else:
    print("not eligibble for vote")
# Out:
# not eligibble for vote

# %%
# Check whether a number is greater than 100 or not.
num = 78

if num > 100:
    print("num if greater than 100")

else:
    print("num is less than 100")
# Out:
# num is less than 100

# %%
# Check whether a password is correct or incorrect.
password = "Python123"

if password == "Python123":
    print("Correct")
else:
    print("Incorrect")
# Out:
# Correct

# %%
# Check whether a person is eligible for a driving license.
age = 20

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
# Check whether a number is zero or non-zero.
num = 0

if num == num :
    print("num is zero")

else:
    print("non zero")
# Out:
# num is zero

# %%
# Check whether a student has passed based on marks.
marks = 75

if marks >= 40:
    print("Passed")
else:
    print("Failed")
# Out:
# Passed

# %%
# Check whether a person is eligible for a job based on age.
age = 25

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
# Check whether a product is available or unavailable based on stock.
stock = 10

if stock > 0:
    print("Available")
else:
    print("Unavailable")
# Out:
# Available

# %%
# Check whether a user is eligible for a discount.
age = 65

if age >= 60:
    print("Eligible for Discount")
else:
    print("Not Eligible for Discount")
# Out:
# Eligible for Discount

# %%
# Check whether a number is divisible by 5 or not.
number = 25

if number % 5 == 0:
    print("Divisible by 5")
else:
    print("Not Divisible by 5")
# Out:
# Divisible by 5

# %%
# Check whether two given values are equal or not.
value1 = 10
value2 = 10

if value1 == value2:
    print("Equal")
else:
    print("Not Equal")
# Out:
# Equal

# %%
# Check whether a person is eligible for a loan based on salary.
salary = 30000

if salary >= 25000:
    print("Eligible for Loan")
else:
    print("Not Eligible for Loan")
# Out:
# Eligible for Loan

# %%
# 🟠 if-elif-else — 26–40
# Print grade based on marks:
# 90+ → A
# 75–89 → B
# 60–74 → C
# 40–59 → D
# Below 40 → F

marks = 76

if marks > 90 :
    print("A")

elif marks >=75 and marks <=89:
    print("B")

elif marks >=60 and marks <= 74:
    print("C")

elif marks >= 40 and marks <= 59:
    print("D")

else:
    print("F")
# Out:
# B

# %%
# Check whether a number is positive, negative, or zero.
num = 8

if num == 0:
    print("Zero")

elif num > 0:
    print("positive")

else:
    print("Negative")
# Out:
# positive

# %%
# Create a program to classify age:
# 0–12 → Child
# 13–19 → Teenager
# 20–59 → Adult
# 60+ → Senior Citizen

age = 23

if age >= 0 and age <= 12:
    print("Child")

elif age >= 13 and age <= 19:
    print("Teenager")

elif age >= 20 and age <= 59:
    print("Adult")

else:
    print("Senior Citizen")
# Out:
# Adult

# %%
# Create a temperature classifier:
# Below 10 → Cold
# 10–25 → Moderate
# 26–35 → Warm
# Above 35 → Hot

temp = 12

if temp < 10:
    print("Cold")

elif temp >= 10 and temp <= 25:
    print("Moderate")

elif temp >= 26 and temp <= 35:
    print("Warm")

else:
    print("Hot")
# Out:
# Moderate

# %%
# Create a marks classification:
# 90+ → Excellent
# 75–89 → Very Good
# 60–74 → Good
# 40–59 → Average
# Below 40 → Fail

marks = 85

if marks >= 90:
    print("Excellent")

elif marks >= 75:
    print("Very Good")

elif marks >= 60:
    print("Good")

elif marks >= 40:
    print("Average")

else:
    print("Fail")
# Out:
# Very Good

# %%
# Check whether a number is positive even, positive odd, negative, or zero.
number = 12

if number == 0:
    print("Zero")

elif number > 0 and number % 2 == 0:
    print("Positive Even")

elif number > 0 and number % 2 != 0:
    print("Positive Odd")

else:
    print("Negative")
# Out:
# Positive Even

# %%
# Create a salary classification:
# Below 20,000 → Low
# 20,000–50,000 → Medium
# 50,001–100,000 → High
# Above 100,000 → Very High

salary = 75000

if salary < 20000:
    print("Low")

elif salary >= 20000 and salary <= 50000:
    print("Medium")

elif salary >= 50001 and salary <= 100000:
    print("High")

else:
    print("Very High")
# Out:
# High

# %%
# Create a BMI category program using if-elif-else.
bmi = 22.5

if bmi < 18.5:
    print("Underweight")

elif bmi < 25:
    print("Normal")

elif bmi < 30:
    print("Overweight")

else:
    print("Obese")
# Out:
# Normal

# %%
# Create a traffic signal program:
# Red → Stop
# Yellow → Wait
# Green → Go
# Anything else → Invalid Signal


signal = "Red"

if signal == "Red":
    print("Stop")

elif signal == "Yellow":
    print("Wait")

elif signal == "Green":
    print("Go")

else:
    print("Invalid Signal")
# Out:
# Stop

# %%
# Create a day classification using day number:
# 1 → Monday
# 2 → Tuesday
# ...
# 7 → Sunday

day = 3

if day == 1:
    print("Monday")

elif day == 2:
    print("Tuesday")

elif day == 3:
    print("Wednesday")

elif day == 4:
    print("Thursday")

elif day == 5:
    print("Friday")

elif day == 6:
    print("Saturday")

elif day == 7:
    print("Sunday")

else:
    print("Invalid Day")
# Out:
# Wednesday

# %%
# Create a month classification using month number.
month = 8

if month == 1:
    print("January")

elif month == 2:
    print("February")

elif month == 3:
    print("March")

elif month == 4:
    print("April")

elif month == 5:
    print("May")

elif month == 6:
    print("June")

elif month == 7:
    print("July")

elif month == 8:
    print("August")

elif month == 9:
    print("September")

elif month == 10:
    print("October")

elif month == 11:
    print("November")

elif month == 12:
    print("December")

else:
    print("Invalid Month")
# Out:
# August

# %%
# Create a simple calculator that performs an operation based on the user's choice.
num1 = 20
num2 = 5
operation = "+"

if operation == "+":
    print(num1 + num2)

elif operation == "-":
    print(num1 - num2)

elif operation == "*":
    print(num1 * num2)

elif operation == "/":
    print(num1 / num2)

else:
    print("Invalid Operation")
# Out:
# 25

# %%
# Create a menu-based program:
# 1 → Python
# 2 → SQL
# 3 → Machine Learning
# 4 → Data Science
choice = 3

if choice == 1:
    print("Python")

elif choice == 2:
    print("SQL")

elif choice == 3:
    print("Machine Learning")

elif choice == 4:
    print("Data Science")

else:
    print("Invalid Choice")
# Out:
# Machine Learning

# %%
# Create a shipping-cost classifier based on package weight.
weight = 7

if weight < 1:
    print("Shipping Cost: ₹50")

elif weight <= 5:
    print("Shipping Cost: ₹100")

elif weight <= 10:
    print("Shipping Cost: ₹200")

else:
    print("Shipping Cost: ₹300")
# Out:
# Shipping Cost: ₹200

# %%
# Create an electricity-bill category based on units consumed.
units = 250

if units <= 100:
    print("Low Bill")

elif units <= 200:
    print("Medium Bill")

elif units <= 500:
    print("High Bill")

else:
    print("Very High Bill")
# Out:
# High Bill

# %%
# 🔴 Real-World / Challenge — 41–50
# Create a Student Result System using marks in 5 subjects and display Pass/Fail.
maths = 75
science = 68
english = 80
history = 55
computer = 72

if maths >= 40 and science >= 40 and english >= 40 and history >= 40 and computer >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
# Create an ATM withdrawal check:
# Check whether the balance is sufficient.
# Check whether the withdrawal amount is valid.
balance = 10000
withdrawal = 5000

if withdrawal <= 0:
    print("Invalid Withdrawal Amount")

elif withdrawal > balance:
    print("Insufficient Balance")

else:
    balance = balance - withdrawal
    print("Withdrawal Successful")
    print("Remaining Balance:", balance)
# Out:
# Withdrawal Successful
# Remaining Balance: 5000

# %%
# Create a Login System using username and password.
username = "Aniket"
password = "Python123"

if username == "Aniket" and password == "Python123":
    print("Login Successful")
else:
    print("Invalid Username or Password")
# Out:
# Login Successful

# %%
# Create an Employee Bonus System based on salary and years of experience.
salary = 60000
experience = 6

if experience >= 5 and salary >= 50000:
    print("20% Bonus")

elif experience >= 3 and salary >= 30000:
    print("10% Bonus")

else:
    print("5% Bonus")
# Out:
# 20% Bonus

# %%
# Create a Movie Ticket Pricing System based on age:
# Child
# Adult
# Senior Citizen
age = 65

if age < 13:
    print("Child")

elif age < 60:
    print("Adult")

else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %%
# Create a Shopping Discount System based on purchase amount:
# Below ₹1,000 → No discount
# ₹1,000–₹4,999 → 5%
# ₹5,000–₹9,999 → 10%
# ₹10,000+ → 20%
amount = 7500

if amount < 1000:
    print("No Discount")

elif amount < 5000:
    print("5% Discount")

elif amount < 10000:
    print("10% Discount")

else:
    print("20% Discount")
# Out:
# 10% Discount

# %%
# Create a Data Science Course Eligibility System based on Python knowledge and basic statistics knowledge.
python_knowledge = True
statistics_knowledge = True

if python_knowledge and statistics_knowledge:
    print("Eligible for Data Science Course")
else:
    print("Not Eligible")
# Out:
# Eligible for Data Science Course

# %%
# Create a Loan Eligibility System based on age, salary, and credit score.
age = 28
salary = 45000
credit_score = 750

if age >= 21 and salary >= 25000 and credit_score >= 700:
    print("Loan Eligible")
else:
    print("Loan Not Eligible")
# Out:
# Loan Eligible
