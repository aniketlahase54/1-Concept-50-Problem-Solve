# %%
# 🟢 LIST — 1–20
# Use the given lists and perform the operation.
# numbers = [10, 20, 30, 40, 50] → Print the first element.
numbers = [10, 20, 30, 40, 50]
print(numbers[0])
# Out:
# 10

# %%
# numbers = [10, 20, 30, 40, 50] → Print the last element.
numbers = [10, 20, 30, 40, 50]
print(numbers[-1])
# Out:
# 50

# %%
# numbers = [10, 20, 30, 40, 50] → Print elements from index 1 to 3.
numbers = [10, 20, 30, 40, 50]
print(numbers[1:4])
# Out:
# [20, 30, 40]

# %%
# numbers = [10, 20, 30, 40, 50] → Reverse the list.
numbers = [10, 20, 30, 40, 50] 
print(numbers[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
# numbers = [10, 20, 30, 40, 50] → Find the length of the list.
print(len(numbers))
# Out:
# 5

# %%
# numbers = [10, 20, 30, 40, 50] → Add 60 using append().
numbers = [10, 20, 30, 40, 50]
numbers.append(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
# numbers = [10, 20, 30, 40, 50] → Add 5 at index 0 using insert().
numbers = [10, 20, 30, 40, 50]
numbers.insert(0,5)
print(numbers)
# Out:
# [5, 10, 20, 30, 40, 50]

# %%
# numbers = [10, 20, 30, 40, 50] → Remove 30 using remove().
numbers = [10, 20, 30, 40, 50]
numbers.remove(30)
print(numbers)
# Out:
# [10, 20, 40, 50]

# %%
# numbers = [10, 20, 30, 40, 50] → Remove the last element using pop().
numbers = [10, 20, 30, 40, 50]
numbers.pop()
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
# numbers = [10, 20, 30, 40, 50] → Count how many times 20 occurs.
numbers = [10, 20, 30, 40, 50]
numbers.count(20)
# Out:
# 1

# %%
# numbers = [40, 10, 50, 20, 30] → Sort in ascending order.
numbers = [40, 10, 50, 20, 30] 
numbers.sort()
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
# numbers = [40, 10, 50, 20, 30] → Sort in descending order.
numbers = [40, 10, 50, 20, 30]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [50, 40, 30, 20, 10]

# %%
# numbers = [10, 20, 30, 20, 40, 20] → Count 20.
numbers = [10, 20, 30, 20, 40, 20]
numbers.count(20)
# Out:
# 3

# %%
# numbers = [10, 20, 30, 40, 50] → Find the index of 40.
numbers = [10, 20, 30, 40, 50]
numbers.index(40)
# Out:
# 3

# %%
# numbers = [10, 20, 30] → Add [40, 50] using extend().
numbers = [10, 20, 30]
numbers.extend([40,50])
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
# names = ["Aniket", "Rahul", "Priya"] → Change "Rahul" to "Amit".
names = ["Aniket", "Rahul", "Priya"]
names[1] = "Amit"
print(names)
# Out:
# ['Aniket', 'Amit', 'Priya']

# %%
# names = ["Aniket", "Rahul", "Priya"] → Check whether "Aniket" exists.
names = ["Aniket", "Rahul", "Priya"]
print("Aniket" in names)
# Out:
# True

# %%
# numbers = [10, 20, 30, 40, 50] → Create a copy of the list.
numbers = [10, 20, 30, 40, 50] 
copy = numbers.copy()
print(copy)
# Out:
# [10, 20, 30, 40, 50]

# %%
# numbers = [1, 2, 3, 4, 5] → Clear all elements.
numbers = [1, 2, 3, 4, 5]
numbers.clear()
print(numbers)
# Out:
# []

# %%
# 🟡 TUPLE — 21–32
# data = (10, 20, 30, 40, 50) → Print the first element.
data = (10, 20, 30, 40, 50)
data[0]
# Out:
# 10

# %%
# data = (10, 20, 30, 40, 50) → Print the last element.
data[-1]
# Out:
# 50

# %%
# data = (10, 20, 30, 40, 50) → Print the length.
len(data)
# Out:
# 5

# %%
# data = (10, 20, 30, 40, 50) → Slice the first three elements.
data[:3]
# Out:
# (10, 20, 30)

# %%
# data = (10, 20, 30, 20, 40) → Count 20.
data = (10, 20, 30, 20, 40)
data.count(20)
# Out:
# 2

# %%
# data = (10, 20, 30, 40, 50) → Find the index of 30.
data = (10, 20, 30, 40, 50)
data.index(30)
# Out:
# 2

# %%
# data = (10, 20, 30) → Check whether 20 exists.
data = (10, 20, 30)
print(20 in data)
# Out:
# True

# %%
# data = ("Python", "SQL", "ML") → Print every element.
data = ("Python", "SQL", "ML")
print(data)
# Out:
# ('Python', 'SQL', 'ML')

# %%
# data = ("Python", "SQL", "Python", "ML") → Count "Python".
data = ("Python", "SQL", "Python", "ML")
data.count("Python")
# Out:
# 2

# %%
# data = (10, 20, 30, 40, 50) → Reverse it using slicing.
data = (10, 20, 30, 40, 50)
print(data[::-1])
# Out:
# (50, 40, 30, 20, 10)

# %%
# Convert data = [10, 20, 30, 40] into a tuple.
data = [10, 20, 30, 40]
data =tuple(data)
print(type(data))
print(data)
# Out:
# <class 'tuple'>
# (10, 20, 30, 40)

# %%
# Convert data = (10, 20, 30, 40) into a list.
data = [10, 20, 30, 40]
data =list(data)
print(type(data))
print(data)
# Out:
# <class 'list'>
# [10, 20, 30, 40]

# %%
# 🔵 SET — 33–44
# numbers = {10, 20, 30, 40} → Add 50.
numbers = {10, 20, 30, 40}
numbers.add(50)
print(numbers)
# Out:
# {40, 10, 50, 20, 30}

# %%
# numbers = {10, 20, 30, 40} → Remove 20.
numbers = {10, 20, 30, 40}
numbers.remove(20)
print(numbers)
# Out:
# {40, 10, 30}

# %%
# numbers = {10, 20, 30, 40} → Check whether 30 exists.
numbers = {10, 20, 30, 40}
print(30 in numbers)
# Out:
# True

# %%
# numbers = {10, 20, 30, 40} → Find the number of elements.
numbers = {10, 20, 30, 40}

print(len(numbers))
# Out:
# 4

# %%
# numbers = {10, 20, 30, 40} → Remove all elements.
numbers = {10, 20, 30, 40}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
# a = {1, 2, 3, 4} and b = {3, 4, 5, 6} → Find the union.
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
c = a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# a = {1, 2, 3, 4} and b = {3, 4, 5, 6} → Find the intersection.
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
c = a.intersection(b)
print(c)
# Out:
# {3, 4}

# %%
# a = {1, 2, 3, 4} and b = {3, 4, 5, 6} → Find a - b.
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

c = a.difference(b)
print(c)
# Out:
# {1, 2}

# %%
# numbers = [1, 2, 2, 3, 3, 4, 5, 5] → Remove duplicates using a set.
numbers = [1, 2, 2, 3, 3, 4, 5, 5]
numbers = set(numbers)
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
# a = {1, 2, 3} and b = {1, 2, 3, 4} → Check whether a is a subset of b.
a = {1, 2, 3}
b = {1, 2, 3, 4}

print(a.issubset(b))
# Out:
# True

# %%
# a = {1, 2, 3, 4} and b = {1, 2, 3} → Check whether a is a superset of b.
a = {1, 2, 3, 4}
b = {1, 2, 3}

print(a.issubset(b))
# Out:
# False

# %%
# 🟣 DICTIONARY — 45–55
# student = {"name": "Aniket", "age": 21, "course": "Data Science"} → Print the name.
student = {"name": "Aniket", "age": 21, "course": "Data Science"}
print(student.get("name"))
# Out:
# Aniket

# %%
# Using the same dictionary → Print all keys.
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
# Using the same dictionary → Print all values.
print(student.values())
# Out:
# dict_values(['Aniket', 21, 'Data Science'])

# %%
# Using the same dictionary → Add "city": "Pune".
student.update({"city": "Pune"})
print(student)
# Out:
# {'name': 'Aniket', 'age': 21, 'course': 'Data Science', 'city': 'Pune'}

# %%
# Using the same dictionary → Change the age to 22.
student.update({"age" : 23})
print(student)
# Out:
# {'name': 'Aniket', 'age': 23, 'course': 'Data Science', 'city': 'Pune'}

# %%
# Using the same dictionary → Remove "course".
student.pop("course")

print(student)
# Out:
# {'name': 'Aniket', 'age': 21}

# %%
# Check whether "name" exists as a key.
print("name" in student)
# Out:
# True

# %%
# Use get() to access "age".
student.get("age")
# Out:
# 21

# %%
# Use items() to print key-value pairs.
student.items()
# Out:
# dict_items([('name', 'Aniket'), ('age', 21)])

# %%
# marks = {"Python": 85, "SQL": 78, "ML": 90} → Find the highest-mark subject.
marks = {"Python": 85, "SQL": 78, "ML": 90}

highest_subject = max(marks, key=marks.get)

print(highest_subject)
# Out:
# ML

# %%
# Create a dictionary containing name, age, city, education, and skills.

data = {
    "name" : "aniket",
    "age" : 23,
    "city" : "jalgaon",
    "education" : "BE",
    "skills" : ["python","sql","ml"]
    
}
print(data)
# Out:
# {'name': 'aniket', 'age': 23, 'city': 'jalgaon', 'education': 'BE', 'skills': ['python', 'sql', 'ml']}

# %%
# Create a dictionary where each student has a list of marks:
# students = {
#     "Aniket": [85, 90, 78],
#     "Rahul": [70, 75, 80]
# }

# Print Aniket's marks.

students = {
    "Aniket": [85, 90, 78],
    "Rahul": [70, 75, 80]
}

print(students.get("Aniket"))
# Out:
# [85, 90, 78]

# %%
# Create a dictionary containing student information:
# student = {
#     "name": "Aniket",
#     "age": 21,
#     "skills": ["Python", "SQL", "Machine Learning"],
#     "education": {
#         "degree": "BSc",
#         "field": "Data Science"
#     }
# }

# Access and print "Machine Learning".

student = {
    "name": "Aniket",
    "age": 21,
    "skills": ["Python", "SQL", "Machine Learning"],
    "education": {
        "degree": "BSc",
        "field": "Data Science"
    }
}

print(student["skills"][2])
# Out:
# Machine Learning

# %%
# 🚀 Mini Project — Student Data Management

# Create a program using List + Dictionary + Tuple + Set to store:

# Student name
# Age
# Course
# Skills
# Marks
# Unique subjects

# Then display the complete student profile.
