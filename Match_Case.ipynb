# %%
# 🟢 Basic match-case — 1–15
# Match a number  1–3 and print "One", "Two", or "Three".
number = 1

match number:
    case 1:
        print("ONE")

    case 2:
        print("TWO")

    case 3:
        print("THREE")

    case _:
        print("Invalid Numbers")
# Out:
# ONE

# %%
# Match a day number 1–7 and print the day name.
day = 7

match day:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case 7:
        print("Sunday")
    case _:
        print("Invalid day")
# Out:
# Sunday

# %%
# Match a month number 1–12 and print the month name.
month = 4

match month:
    case 1:
        print("January")
    case 2:
        print("February")
    case 3:
        print("March")
    case 4:
        print("April")
    case 5:
        print("May")
    case 6:
        print("June")
    case 7:
        print("July")
    case 8:
        print("August")
    case 9:
        print("September")
    case 10:
        print("October")
    case 11:
        print("November")
    case 12:
        print("December")
    case _:
        print("Invalid month")
# Out:
# April

# %%
# Match a traffic signal: "red", "yellow", "green".
signal = "red"

match signal:
    case "red":
        print("Stop")
    case "yellow":
        print("Wait")
    case "green":
        print("Go")
    case _:
        print("Invalid signal")
# Out:
# Stop

# %%
# Match a grade: "A", "B", "C", "D", "F".
grade = "C"
match grade:
    case "A":
        print("Excellent")
    case "B":
        print("Very Good")
    case "C":
        print("Good")
    case "D":
        print("Pass")
    case "F":
        print("Fail")
    case _:
        print("Invalid grade")
# Out:
# Good

# %%
# Match a menu choice 1–4 and print the selected option.
choice = 3

match choice:
    case 1: 
        print("Option 1 selected")
    case 2: 
        print("Option 2 selected")
    case 3: 
        print("Option 3 selected")
    case 4: 
        print("Option 4 selected")
    case _: 
        print("Invalid choice")
# Out:
# Option 3 selected

# %%
# Match a calculator operator: +, -, *, /.
operator = "*"
match operator:
    case "+": 
        print("Addition")
    case "-": 
        print("Subtraction")
    case "*":
        print("Multiplication")
    case "/":
        print("Division")
    case _:
        print("Invalid operator")
# Out:
# Multiplication

# %%
# Match "male", "female", "other" and print a suitable message.
gender = "male"

match gender:
    case "male": 
        print("You selected Male")
    case "female": 
        print("You selected Female")
    case "other": 
        print("You selected Other")
    case _: 
        print("Invalid input")
# Out:
# You selected Male

# %%
# Match "admin", "user", "guest" and print the role.
role = "guest"
match role:
    case "admin": 
        print("Admin")
    case "user":
        print("User")
    case "guest":
        print("Guest")
    case _: 
        print("Invalid role")
# Out:
# Guest

# %%
# Match "morning", "afternoon", "evening", "night".

time = "morning"

match time:
    case "morning": 
        print("Good Morning")
    case "afternoon":
        print("Good Afternoon")
    case "evening": 
        print("Good Evening")
    case "night": 
        print("Good Night")
    case _: print("Invalid time")
# Out:
# Good Morning

# %%
# 🟡 match-case with Conditions — 16–30
# Match a number and identify whether it is 0, positive, or negative using a guard.
num = 5

match num:
    case num if num > 0:
        print("Positive")
    case num if num < 0:
        print("Negative")
    case 0:
        print("Zero")
# Out:
# Positive

# %%
# Match marks and classify them as pass/fail using a guard.
marks = 45

match marks:
    case marks if marks >= 40:
        print("Pass")
    case marks if marks < 40:
        print("Fail")
# Out:
# Pass

# %%
# Match age and classify as child, teenager, adult, or senior.
age = 23

match age:
    case age if age < 13:
        print("Child")
    case age if age < 20:
        print("Teenager")
    case age if age < 60:
        print("Adult")
    case age if age >= 60:
        print("Senior")
# Out:
# Adult

# %%
# Match temperature and classify as cold, moderate, warm, or hot.
temp = 33

match temp:
    case temp if temp < 10:
        print("Cold")
    case temp if temp < 25:
        print("Moderate")
    case temp if temp < 35:
        print("Warm")
    case temp if temp >= 35:
        print("Hot")
# Out:
# Warm

# %%
# Match salary and classify it into salary ranges.
salary = 25000

match salary:
    case salary if salary < 25000:
        print("Low Salary")
    case salary if salary < 50000:
        print("Medium Salary")
    case salary if salary < 100000:
        print("High Salary")
    case salary if salary >= 100000:
        print("Very High Salary")
# Out:
# Medium Salary

# %%
# Match a number and identify whether it is divisible by 5.
num = 53

match num:
    case num if num % 5 == 0:
        print("Divisible by 5")
    case _:
        print("Not divisible by 5")
# Out:
# Not divisible by 5

# %%
# Match a number and identify whether it is divisible by both 3 and 5.
num = 15

match num:
    case num if num % 3 == 0 and num % 5 == 0:
        print("Divisible by both 3 and 5")
    case _:
        print("Not divisible by both 3 and 5")
# Out:
# Divisible by both 3 and 5

# %%
# Match a score and print "Excellent", "Good", "Average", or "Fail".
score = 54

match score:
    case score if score >= 90:
        print("Excellent")
    case score if score >= 70:
        print("Good")
    case score if score >= 40:
        print("Average")
    case _:
        print("Fail")
# Out:
# Average

# %%
# Match shopping amount and calculate the discount category.
amount = 5500

match amount:
    case amount if amount >= 10000:
        print("20% Discount")
    case amount if amount >= 5000:
        print("10% Discount")
    case amount if amount >= 2000:
        print("5% Discount")
    case _:
        print("No Discount")
# Out:
# 10% Discount

# %%
# Match age and determine voting eligibility.
age = 15
match age:
    case age if age >= 18:
        print("Eligible to Vote")
    case _:
        print("Not Eligible to Vote")
# Out:
# Not Eligible to Vote

# %%
# Match a number and check whether it is between 1 and 100.
num = 44

match num:
    case num if 1 <= num <= 100:
        print("Number is between 1 and 100")
    case _:
        print("Number is outside the range")
# Out:
# Number is between 1 and 100

# %%
# Match BMI and classify it into health categories.
bmi = 22

match bmi:
    case bmi if bmi < 18.5:
        print("Underweight")
    case bmi if bmi < 25:
        print("Normal")
    case bmi if bmi < 30:
        print("Overweight")
    case _:
        print("Obese")
# Out:
# Normal

# %%
# Match speed and classify it as slow, normal, fast, or overspeed.
speed = 55

match speed:
    case speed if speed < 40:
        print("Slow")
    case speed if speed < 60:
        print("Normal")
    case speed if speed < 80:
        print("Fast")
    case _:
        print("Overspeed")
# Out:
# Normal

# %%
# 🔵 Calculator & Menu Problems — 31–40
# Create a calculator using match-case.
num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

match operator:
    case "+":
        print(num1 + num2)
    case "-":
        print(num1 - num2)
    case "*":
        print(num1 * num2)
    case "/":
        if num2 != 0:
            print(num1 / num2)
        else:
            print("Cannot divide by zero")
    case _:
        print("Invalid operator")
# Out:
# Enter first number:  12
# Enter operator (+, -, *, /):  *
# Enter second number:  5
# 60.0

# %%
# Create a menu for 1. Add 2. Subtract 3. Multiply 4. Divide.
choice = int(input("Enter choice (1-4): "))
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

match choice:
    case 1:
        print("Result:", a + b)
    case 2:
        print("Result:", a - b)
    case 3:
        print("Result:", a * b)
    case 4:
        print("Result:", a / b if b != 0 else "Cannot divide by zero")
    case _:
        print("Invalid choice")
# Out:
# Enter choice (1-4):  2
# Enter first number:  42
# Enter second number:  12
# Result: 30.0

# %%
# Create a restaurant menu using match-case.
choice = 3

match choice:
    case 1: 
        print("Pizza - ₹200")
    case 2: 
        print("Burger - ₹120")
    case 3: 
        print("Pasta - ₹150")
    case 4: 
        print("Coffee - ₹80")
    case _: 
        print("Invalid choice")
# Out:
# Pasta - ₹150

# %%
# Create a bank menu: 1. Balance 2. Deposit 3. Withdraw.
balance = 10000

choice = int(input("Enter choice (1-3): "))

match choice:
    case 1:
        print("Balance:", balance)

    case 2:
        amount = float(input("Enter deposit amount: "))
        balance += amount
        print("New Balance:", balance)

    case 3:
        amount = float(input("Enter withdrawal amount: "))
        if amount <= balance:
            balance -= amount
            print("New Balance:", balance)
        else:
            print("Insufficient Balance")

    case _:
        print("Invalid choice")
# Out:
# Enter choice (1-3):  2
# Enter deposit amount:  5000
# New Balance: 15000.0

# %%
# Create a simple ATM menu.
balance = 10000

choice = int(input("1. Balance\n2. Deposit\n3. Withdraw\n4. Exit\nEnter choice: "))

match choice:
    case 1:
        print("Balance:", balance)
    case 2:
        amount = float(input("Enter deposit amount: "))
        balance += amount
        print("New Balance:", balance)
    case 3:
        amount = float(input("Enter withdrawal amount: "))
        if amount <= balance:
            balance -= amount
            print("New Balance:", balance)
        else:
            print("Insufficient Balance")
    case 4:
        print("Thank you!")
    case _:
        print("Invalid choice")
# Out:
# 1. Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter choice:  2
# Enter deposit amount:  21000
# New Balance: 31000.0

# %%
# Create a unit converter for cm, m, and km.
value = float(input("Enter value: "))
unit = input("Enter unit (cm, m, km): ").lower()

match unit:
    case "cm":
        print("Meters:", value / 100)
        print("Kilometers:", value / 100000)

    case "m":
        print("Centimeters:", value * 100)
        print("Kilometers:", value / 1000)

    case "km":
        print("Meters:", value * 1000)
        print("Centimeters:", value * 100000)

    case _:
        print("Invalid unit")
# Out:
# Enter value:  12000
# Enter unit (cm, m, km):  m
# Centimeters: 1200000.0
# Kilometers: 12.0

# %%
# Create a menu for List operations: add, remove, search, display.
items = []

choice = input("Enter operation (add, remove, search, display): ").lower()

match choice:
    case "add":
        item = input("Enter item: ")
        items.append(item)
        print("Item added")

    case "remove":
        item = input("Enter item: ")
        if item in items:
            items.remove(item)
            print("Item removed")
        else:
            print("Item not found")

    case "search":
        item = input("Enter item: ")
        if item in items:
            print("Item found")
        else:
            print("Item not found")

    case "display":
        print("List:", items)

    case _:
        print("Invalid operation")
# Out:
# Enter operation (add, remove, search, display):  add
# Enter item:  45
# Item added

# %%
# 🚀 Mini Project: Build a Student Management System using match-case with options:
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit


students = {}

while True:
    print("\n--- Student Management System ---")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Exit")

    choice = input("Enter choice: ")

    match choice:

        case "1":
            roll_no = input("Enter Roll No: ")
            name = input("Enter Name: ")
            age = int(input("Enter Age: "))

            students[roll_no] = {
                "name": name,
                "age": age
            }

            print("Student added successfully!")

        case "2":
            if students:
                print("\n--- Student List ---")

                for roll_no, details in students.items():
                    print(
                        f"Roll No: {roll_no}, "
                        f"Name: {details['name']}, "
                        f"Age: {details['age']}"
                    )
            else:
                print("No students found.")

        case "3":
            roll_no = input("Enter Roll No to search: ")

            if roll_no in students:
                student = students[roll_no]
                print("Student Found!")
                print("Name:", student["name"])
                print("Age:", student["age"])
            else:
                print("Student not found.")

        case "4":
            roll_no = input("Enter Roll No to update: ")

            if roll_no in students:
                name = input("Enter new name: ")
                age = int(input("Enter new age: "))

                students[roll_no]["name"] = name
                students[roll_no]["age"] = age

                print("Student updated successfully!")
            else:
                print("Student not found.")

        case "5":
            roll_no = input("Enter Roll No to delete: ")

            if roll_no in students:
                del students[roll_no]
                print("Student deleted successfully!")
            else:
                print("Student not found.")

        case "6":
            print("Thank you!")
            break

        case _:
            print("Invalid choice. Please try again.")
# Out:
# --- Student Management System ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter choice:  1
# Enter Roll No:  01
# Enter Name:  Aniket
