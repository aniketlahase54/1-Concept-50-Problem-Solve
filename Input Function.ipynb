# %%
# Ask the user to enter their name and print it.
name = input("enter the name")
print("welcome",name)
# Out:
# enter the name aniket
# welcome aniket

# %%
# Ask the user to enter their age and print it.
age = int(input("enter the age"))
print("your age is :",age)
# Out:
# enter the age 23
# your age is : 23

# %%
# Ask the user to enter their city and print it.
city = input("enter the city")
print(city)
# Out:
# enter the city Jalgaon
# Jalgaon

# %%
# Ask the user to enter their college name and print it.
clg_name = input("enter the clg name")
print(clg_name)
# Out:
# enter the clg name SSBT COET JALGAON
# SSBT COET JALGAON

# %%
# Ask the user to enter their course name and print it.
course_name = input("enter the course name")
print(course_name)
# Out:
# enter the course name Computer
# Computer

# %%
# Ask the user to enter their favorite programming language and print it.
fav_lang = input("enter the favorite programming language")
print(fav_lang)
# Out:
# enter the favorite programming language python
# python

# %%
# Ask the user to enter their country and print it.
country = input("enter the country ")
print(country)
# Out:
# enter the country  India
# India

# %%
# Ask the user to enter their profession and print it.
profession = input("Enter your profession: ")
print("Your profession is:", profession)
# Out:
# Enter your profession:  Data Scientist
# Your profession is: Data Scientist

# %%
# Ask the user to enter their favorite color and print it.
fav_col = input("enter the favorite color")
print("your favorite color is:",fav_col)
# Out:
# enter the favorite color Blue
# your favorite color is: Blue

# %%
# Ask the user to enter their favorite food and print it.
fav_food = input("enter the favorite food")
print("your favorite color is:",fav_food)
# Out:
# enter the favorite food Pasta
# your favorite color is: Pasta

# %%
# Take first name and last name as separate inputs and display both.
first_name = input("enter the first name")
last_name = input("enter the last name")
print(first_name,"",last_name)
# Out:
# enter the first name Aniket
# enter the last name Lahase
# Aniket  Lahase

# %%
# Take name and city as separate inputs and display both.
name = input("Enter your name: ")
city = input("Enter your city: ")

print("Name:", name)
print("City:", city)
# Out:
# Enter your name:  Aniket
# Enter your city:  Jalgaon
# Name: Aniket
# City: Jalgaon

# %%
# Take name, age, and city as inputs and display all three.
name = input("enter the name ")
age = int(input("enter the age "))
city = input("enter the city name ")
print("name :",name)
print("age :",age)
print("city :",city)
# Out:
# enter the name  Aniket
# enter the age  23
# enter the city name  Jalgaon
# name : Aniket
# age : 23
# city : Jalgaon

# %%
# Take college, course, and year as inputs and display them.
college = input("Enter your college: ")
course = input("Enter your course: ")
year = input("Enter your year: ")

print("College:", college)
print("Course:", course)
print("Year:", year)
# Out:
# Enter your college:  SBST College of Engineering
# Enter your course:   Computer Science Engineering..
# Enter your year:  2026
# College: SBST College of Engineering
# Course:  Computer Science Engineering..
# Year: 2026

# %%
# Take name, profession, and countrycountry as inputs and display a basic profile.
name  = input("Enter your name: ")
profession = input("Enter your profession: ")
country = input("Enter your country: ")

print("College:", name)
print("Course:", profession)
print("Year:", country)
# Out:
# Enter your name:  aniket
# Enter your profession:  Data Scientist
# Enter your country:  India
# College: aniket
# Course: Data Scientist
# Year: India

# %%
# Take two values from the user using two input() statements.
value1 = int(input("Enter first value: "))
value2 = int(input("Enter second value: "))

print("First value:", value1)
print("Second value:", value2)
# Out:
# Enter first value:  12
# Enter second value:  3
# First value: 12
# Second value: 3

# %%
# Take three values using three separate input() statements.
value1 = int(input("Enter first value: "))
value2 = int(input("Enter second value: "))
value3 = int(input("Enter third value: "))

print("First value:", value1)
print("Second value:", value2)
print("third value:", value3)
# Out:
# Enter first value:  12
# Enter second value:  3
# Enter third value:  456
# First value: 12
# Second value: 3
# third value: 456

# %%
# Take five names from the user using five input() statements.
name1 = input("Enter first name: ")
name2 = input("Enter second name: ")
name3 = input("Enter third name: ")
name4 = input("Enter fourth name: ")
name5 = input("Enter fifth name: ")

print(name1)
print(name2)
print(name3)
print(name4)
print(name5)
# Out:
# Enter first name:  aniket
# Enter second name:  om
# Enter third name:  kartik
# Enter fourth name:  vaibhav
# Enter fifth name:  munna
# aniket
# om
# kartik
# vaibhav
# munna

# %%
# Take student's name and roll number as input.
name = input("Enter student's name: ")
roll_number = int(input("Enter roll number: "))

print("Name:", name)
print("Roll Number:", roll_number)
# Out:
# Enter student's name:  aniket
# Enter roll number:  08
# Name: aniket
# Roll Number: 8

# %%
# Take employee name and employee ID as input.
employee_name = input("Enter employee name: ")
employee_id = int(input("Enter employee ID: "))

print("Employee Name:", employee_name)
print("Employee ID:", employee_id)
# Out:
# Enter employee name:  aniket
# Enter employee ID:  001
# Employee Name: aniket
# Employee ID: 1

# %%
# Take product name and product category as input.
product_name = input("Enter product name: ")
product_category = input("Enter product category: ")

print("Product Name:", product_name)
print("Product Category:", product_category)
# Out:
# Enter product name:  laptop
# Enter product category:  Electronics
# Product Name: laptop
# Product Category: Electronics

# %%
# Take book name and author name as input.
book_name = input("Enter book name: ")
author_name = input("Enter author name: ")

print("Book Name:", book_name)
print("Author Name:", author_name)
# Out:
# Enter book name:  Atomic Habits
# Enter author name:  James Clear
# Book Name: Atomic Habits
# Author Name: James Clear

# %%
# Take movie name and actor name as input.
movie_name = input("Enter movie name: ")
actor_name = input("Enter actor name: ")

print("Movie Name:", movie_name)
print("Actor Name:", actor_name)
# Out:
# Enter movie name:  3 Idiots
# Enter actor name:  Aamir Khan
# Movie Name: 3 Idiots
# Actor Name: Aamir Khan

# %%
# Take company name and job role as input.
company_name = input("Enter company name: ")
job_role = input("Enter job role: ")

print("Company Name:", company_name)
print("Job Role:", job_role)
# Out:
# Enter company name:  TCS
# Enter job role:  Data Scientist
# Company Name: TCS
# Job Role: Data Scientist

# %%
# Take username and email as input.
username = input("Enter username: ")
email = input("Enter email: ")

print("Username:", username)
print("Email:", email)
# Out:
# Enter username:  aniket123
# Enter email:  aniket@gmail.com
# Username: aniket123
# Email: aniket@gmail.com

# %%
# Take name, age, gender, and city as input.
name = input("Enter name: ")
age = int(input("Enter age: "))
gender = input("Enter gender: ")
city = input("Enter city: ")

print("Name:", name)
print("Age:", age)
print("Gender:", gender)
print("City:", city)
# Out:
# Enter name:  Aniket
# Enter age:  22
# Enter gender:  male
# Enter city:  Jalgaon
# Name: Aniket
# Age: 22
# Gender: male
# City: Jalgaon

# %%
# Take student name, college, course, and specialization as input.
student_name = input("Enter student name: ")
college = input("Enter college: ")
course = input("Enter course: ")
specialization = input("Enter specialization: ")

print("Student Name:", student_name)
print("College:", college)
print("Course:", course)
print("Specialization:", specialization)
# Out:
# Enter student name:  aniket
# Enter college:  SBST College of Engineering
# Enter course:  B.E
# Enter specialization:  Computer Science
# Student Name: aniket
# College: SBST College of Engineering
# Course: B.E
# Specialization: Computer Science

# %%
# Take employee name, department, designation, and location as input.
employee_name = input("Enter employee name: ")
department = input("Enter department: ")
designation = input("Enter designation: ")
location = input("Enter location: ")

print("Employee Name:", employee_name)
print("Department:", department)
print("Designation:", designation)
print("Location:", location)
# Out:
# Enter employee name:  aniket lahase
# Enter department:  Data Science
# Enter designation:  Data Scientist
# Enter location:  pune
# Employee Name: aniket lahase
# Department: Data Science
# Designation: Data Scientist
# Location: pune

# %%
# Take product name, brand, category, and size as input.
product_name = input("Enter product name: ")
brand = input("Enter brand: ")
category = input("Enter category: ")
size = input("Enter size: ")

print("Product Name:", product_name)
print("Brand:", brand)
print("Category:", category)
print("Size:", size)
# Out:
# Enter product name:  T-Shirt
# Enter brand:  Nike
# Enter category:  Clothing
# Enter size:  L
# Product Name: T-Shirt
# Brand: Nike
# Category: Clothing
# Size: L

# %%
# Take a user's name, city, country, profession, and hobby as input.
name = input("Enter your name: ")
city = input("Enter your city: ")
country = input("Enter your country: ")
profession = input("Enter your profession: ")
hobby = input("Enter your hobby: ")

print("Name:", name)
print("City:", city)
print("Country:", country)
print("Profession:", profession)
print("Hobby:", hobby)
# Out:
# Enter your name:  aniket
# Enter your city:  pune'
# Enter your country:  india
# Enter your profession:  data scientist
# Enter your hobby:  coding
# Name: aniket
# City: pune'
# Country: india
# Profession: data scientist
# Hobby: coding

# %%
# Create a student information program using input().

# %%
# Create an employee information program using input().

# %%
# Create a customer information program using input().

# %%
# Create a product information program using input().

# %%
# Create a college admission information program using input().

# %%
# Create a job applicant information program using input().

# %%
# Create a simple user registration form using input().

# %%
# Create a simple login information form using input().

# %%
# Create a travel information form using input().

# %%
# Create a personal profile form using input().

# %%
# Take 5 personal details from the user and display them.

# %%
# Take 5 student details and display them as a profile.

# %%
# Take 5 employee details and display them as an employee profile.

# %%
# Take 5 product details and display them as a product profile.

# %%
# Take user's name, city, education, skills, and career goal as input.

# %%
# Take student name, college, course, branch, and career goal as input.

# %%
# Take developer name, programming language, experience, role, and company as input.

# %%
# Create a complete Data Science learner profile using 8 input() statements.

# %%
# Create a GitHub profile information program using input().

# %%
# Create a Data Science Registration Form using input() with at least 10 different questions.
