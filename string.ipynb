# %%
# text = "Python Programming" → Print the first character.
text = "Python Programming"
print(text[0])
# Out:
# P

# %%
# text = "Data Science" → Print the last character.
text = "Data Science"
print(text[-1])
# Out:
# e

# %%
# text = "Machine Learning" → Print the 3rd character.
text = "Machine Learning"
print(text[2])
# Out:
# c

# %%
# text = "Python Developer" → Print the 5th character.
text = "Python Developer"
print(text[4])
# Out:
# o

# %%
# text = "Data Science" → Print the second-last character.
text = "Data Science"
print(text[-2])
# Out:
# c

# %%
# text = "Artificial Intelligence" → Print the character at index 5.
text = "Artificial Intelligence"
print(text[5])
# Out:
# i

# %%
# text = "Python Programming" → Print the first 6 characters using indexing.
text = "Python Programming"
print(text[0:6])
# Out:
# Python

# %%
# text = "Data Science" → Print the character at index 2.
text = "Data Science"
print(text[2])
# Out:
# t

# %%
# text = "Machine Learning" → Print the character at index -3.
text = "Machine Learning"
print(text[-3])
# Out:
# i

# %%
# text = "Python" → Print every character using indexing.
text = "Python"
print(text[0:])
# Out:
# Python

# %%
# text = "Data Science" → Print the first and last character.
text = "Data Science"
print(text[0])
print(text[-1])
# Out:
# D
# e

# %%
# text = "Python Programming" → Print characters at indexes 0, 3, and 6.
text = "Python Programming"
print(text[0])
print(text[3])
print(text[6])
# Out:
# P
# h

# %%
# text = "Machine Learning" → Print the middle character.
text = "Machine Learning"

print(text[7])
print(text[8])
# Out:
#
# L

# %%
# text = "Data Scientist" → Print the character before "S".
text = "Data Scientist"

print(text[4])

# %%
# text = "Python Developer" → Print the last 3 characters using negative indexing.
text = "Python Developer"
print(text[-3:])
# Out:
# per

# %%
# text = "Python Programming" → Extract "Python".
text = "Python Programming"
print(text[:6])
# Out:
# Python

# %%
# text = "Data Science" → Extract "Data".
text = "Data Science"
print(text[:4])
# Out:
# Data

# %%
# text = "Machine Learning" → Extract "Learning".
text = "Machine Learning"
print(text[8:])
# Out:
# Learning

# %%
# text = "Python Developer" → Extract "Developer".
text = "Python Developer"
print(text[7:])
# Out:
# Developer

# %%
# text = "Artificial Intelligence" → Extract "Artificial".
text = "Artificial Intelligence"
print(text[:10])
# Out:
# Artificial

# %%
# text = "Python Programming" → Print the first 5 characters.
text = "Python Programming"
print(text[:5])
# Out:
# Pytho

# %%
# text = "Data Science" → Print the last 7 characters.
text = "Data Science"
print(text[-7:])
# Out:
# Science

# %%
# text = "Machine Learning" → Print characters from index 2 to 8.
text = "Machine Learning"
print(text[2])
print(text[8])
# Out:
# c
# L

# %%
# text = "Python Programming" → Print characters from index 7 to the end.
text = "Python Programming"
print(text[7:])
# Out:
# Programming

# %%
# text = "Data Science" → Print characters from the beginning to index 4.
text = "Data Science"
print(text[:5])
# Out:
# Data

# %%
# text = "Python Programming" → Print every second character.
text = "Python Programming"
print(text[::2])
# Out:
# Pto rgamn

# %%
# text = "Machine Learning" → Print every third character.
text = "Machine Learning"
print(text[::3])
# Out:
# Mheeng

# %%
# text = "Data Science" → Reverse the string using slicing.
text = "Data Science"
print(text[::-1])
# Out:
# ecneicS ataD

# %%
# text = "Python Programming" → Remove the first character using slicing.
text = "Python Programming"
print(text[1:])
# Out:
# ython Programming

# %%
# text = "Machine Learning" → Remove the last character using slicing.
text = "Machine Learning"
print(text[:-1])
# Out:
# Machine Learnin

# %%
# text = "python programming" → Convert to uppercase using upper().
text = "python programming"
print(text.upper())
# Out:
# PYTHON PROGRAMMING

# %%
# text = "DATA SCIENCE" → Convert to lowercase using lower().
text = "DATA SCIENCE" 
print(text.lower())
# Out:
# data science

# %%
# text = "python data science" → Convert to title case using title().
text = "python data science"
print(text.title())
# Out:
# Python Data Science

# %%
# text = "python programming" → Capitalize using capitalize().
text = "python programming"
print(text.capitalize())
# Out:
# Python programming

# %%
# text = " Python " → Remove spaces using strip().
text = " Python "
print(text.strip())
# Out:
# Python

# %%
# text = "Python Programming" → Count "o" using count().
text = "Python Programming"
print(text.count("o"))
# Out:
# 2

# %%
# text = "I love Python" → Find "Python" using find().
text = "I love Python"
print(text.find("Python"))
# Out:
# 7

# %%
# text = "Python is easy" → Replace "easy" with "powerful".
text = "Python is easy"
print(text.replace("easy","powerful"))
# Out:
# Python is powerful

# %%
# text = "Python Programming" → Check whether it starts with "Python".
text = "Python Programming"
print(text.startswith("Python"))
# Out:
# True

# %%
# text = "Python Programming" → Check whether it ends with "Programming".
text = "Python Programming"
print(text.endswith("Programming"))
# Out:
# True

# %%
# text = "Python123" → Check using isalnum().
text = "Python123"
print(text.isalnum())
# Out:
# True

# %%
# text = "Python" → Check using isalpha().
text = "Python"
print(text.isalpha())
# Out:
# True

# %%
# text = "12345" → Check using isdigit().
text = "12345"
print(text.isdigit())
# Out:
# True

# %%
# text = "python" → Check using islower().
text = "python"
print(text.islower())
# Out:
# True

# %%
# text = "PYTHON" → Check using isupper().
text = "PYTHON"
print(text.isupper())
# Out:
# True

# %%
# text = " python programming "
# → Strip spaces → convert to uppercase.
text = " python programming "

print(text.strip().upper())
# Out:
# PYTHON PROGRAMMING

# %%
# text = "data science with python"
# → Convert to title case → print the first 4 characters.
text = "data science with python"

print(text.title()[:4])
# Out:
# Data

# %%
# text = "Python is easy to learn"
# → Count "e" → find "easy" → replace "easy" with "powerful".
text = "Python is easy to learn"

print(text.count("e"))
print(text.replace("easy","powerful"))
# Out:
# 2
# Python is powerful to learn

# %%
# text = " Machine Learning "
# → Strip spaces → convert to lowercase → reverse using slicing.
text = " Machine Learning "
print(text.strip().lower()[-1])
# Out:
# g

# %%
# String Challenge
# text = "  Python is Powerful and Easy to Learn  "

# Perform:

# strip()
# upper()
# lower()
# title()
# First character
# Last character
# First 6 characters
# Last 5 characters
# Reverse the string
# Count "o"
# Find "Powerful"
# Replace "Python" with "Data Science"
