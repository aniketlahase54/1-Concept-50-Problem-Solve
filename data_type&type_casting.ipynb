# %%
# Create an int variable and print its type.
age = 23
print(type(age))
# Out:
# <class 'int'>

# %%
# Create a float variable and print its type.
height = 5.5
print(type(height))
# Out:
# <class 'float'>

# %%
# Create a complex variable and print its type.
num = 10 + 7j
print(type(num))
# Out:
# <class 'complex'>

# %%
# Create a bool variable and print its type.
student = True
print(type(student))
# Out:
# <class 'bool'>

# %%
# Create a str variable and print its type.
name = "aniket"
print(type(name))
# Out:
# <class 'str'>

# %%
# Create a list and print its type.
num = [1,3,5,6,8]
print(type(num))
# Out:
# <class 'list'>

# %%
# Create a tuple and print its type.
num = (1,2,3,4,5)
print(type(num))
# Out:
# <class 'tuple'>

# %%
# Create a set and print its type.
num = {1,2,3,4,5,6}
print(type(num))
# Out:
# <class 'set'>

# %%
# Create a dictionary and print its type.
data = {
    "name" : "aniket",
    age : 23,
    "dept" : "comp"
}

print(type(data))
# Out:
# <class 'dict'>

# %%
# Create a variable with None and print its type.
num = None
print(type(num))
# Out:
# <class 'NoneType'>

# %%
# Create a list containing integers and print its type.
num = [1,3,5,6,8]
print(type(num))
# Out:
# <class 'list'>

# %%
# Create a tuple containing strings and print its type.
name = ("aniket","om","kartik","vaibhav")
print(type(name))
# Out:
# <class 'tuple'>

# %%
# Create a set containing numbers and print its type.
num = {1,2,3,4,5,6}
print(type(num))
# Out:
# <class 'set'>

# %%
# Create a dictionary containing student information and print its type.
data = {
    "name" : "aniket",
    age : 23,
    "dept" : "comp"
}

print(type(data))
# Out:
# <class 'dict'>

# %%
# Create a list containing different data types and print its type.
lst = [1,2,3,4,"aniket","om",223.4,44.3,True]
print(type(lst))
# Out:
# <class 'list'>

# %%
# Create a tuple containing different data types and print its type.
data = ("aniket","om",1,23,3,45,33.4,44.2,"kartik",True)
print(type(data))
# Out:
# <class 'tuple'>

# %%
# Create a dictionary containing values of different data types and print its type.
data = {
    "name" : "aniket",
    age : 23,
    "dept" : "comp"
}

print(type(data))
# Out:
# <class 'dict'>

# %%
# Create a nested list and print its type.
lst = [1,2,3,45,[1,2,34],23,4,5]
print(type(lst))
# Out:
# <class 'list'>

# %%
# Create a nested dictionary and print its type.
student = {
    "name": "Aniket",
    "details": {
        "age": 22,
        "course": "Data Science"
    }
}

print(type(student))
# Out:
# <class 'dict'>

# %%
# Create an empty list and check its type.
empty = []
print(type(empty))
# Out:
# <class 'list'>

# %%
# Create an empty tuple and check its type.
empty = ()
print(type(empty))
# Out:
# <class 'tuple'>

# %%
# Create an empty dictionary and check its type.
empty = {}
print(type(empty))
# Out:
# <class 'dict'>

# %%
# Create an empty set correctly and check its type.
empty = set()
print(type(empty))
# Out:
# <class 'set'>

# %%
# Convert the integer 100 into a float.
num = 100
print(float(num))
# Out:
# 100.0

# %%
# Convert the float 25.5 into an integer.
num = 25.5
print(int(num))
# Out:
# 25

# %%
# Convert the integer 500 into a string.
num = 500
print(str(num))
# Out:
# 500

# %%
# Convert the float 99.99 into a string.
num = 25.5
print(str(num))
# Out:
# 25.5

# %%
# Convert the string "100" into an integer.
num = "100"
print(int(num))
# Out:
# 100

# %%
# Convert the string "25.5" into a float.
num = "25.5"
print(float(num))
# Out:
# 25.5

# %%
# Convert 1 into a boolean.
num = 1
print(bool(num))
# Out:
# True

# %%
# Convert 0 into a boolean.
num = 0
print(bool(num))
# Out:
# False

# %%
# Convert "True" into a boolean and observe the result.
value = "True"
print(bool(value))
# Out:
# True

# %%
# Convert an integer into a float and check its type.
num = 100

result = float(num)

print(result)
print(type(result))
# Out:
# 100.0
# <class 'float'>

# %%
# Convert a float into an integer and check its type.
num = 12.5

result = int(num)

print(result)
print(type(result))
# Out:
# 12
# <class 'int'>

# %%
# Convert an integer into a string and check its type.
num = 100

result = str(num)

print(result)
print(type(result))
# Out:
# 100
# <class 'str'>

# %%
# Convert a string number into an integer and check its type.
num = "100"

result = int(num)

print(result)
print(type(result))
# Out:
# 100
# <class 'int'>

# %%
# Convert a string decimal into a float and check its type.
num = "10.52"

result = float(num)

print(result)
print(type(result))
# Out:
# 10.52
# <class 'float'>

# %%
# Convert a list into a tuple.
num = [1,2,3,3,4,5]

result = tuple(num)

print(result)
print(type(result))
# Out:
# (1, 2, 3, 3, 4, 5)
# <class 'tuple'>

# %%
# Convert a tuple into a list.
num = (1,2,3,3,4,5)

result = list(num)

print(result)
print(type(result))
# Out:
# [1, 2, 3, 3, 4, 5]
# <class 'list'>

# %%
# Convert a list into a set.
num = [1,2,3,3,4,5]

result = set(num)

print(result)
print(type(result))

# %%
# Convert a tuple into a set.

# %%
# Convert a set into a list.

# %%
# Convert a set into a tuple.

# %%
# Convert a list of numbers into a tuple and check its type.

# %%
# Convert a tuple of numbers into a list and check its type.

# %%
# Convert a list containing duplicate values into a set.

# %%
# Convert a set back into a list.
